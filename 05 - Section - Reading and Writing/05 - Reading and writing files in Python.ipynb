# %% [markdown]
# > # Reading and writing files in Python

# %% [markdown]
# >### File vs Directory
# >- ___Files___ - All the information you save on your computer is stored in files.
# >- ___Directory___ - Files are stored in directories. A directory is juast a container for files. Directory are also called ___Folders___.

# %% [markdown]
# > - To switch to other drive -> :drive name -> ___:y___
# > - To clear the window -> ___cls___
# > - Directory -> ___>dir___
# > - To get the content of the directory -> ___>ls___
# > - ___ls -al___
# > - To access the file -> ___cd file-name___ -> ___cd program___
# > - To run python file -> ___python file-name___ -> ___python hello.py___
# > - To Check full-path of the Directory -> ___pwd___ and cd

# %% [markdown]
# > ### Slash vs Backslash
# > - Windows paths use the backslash character to seperate the various parts of the path.
# > - In Linux or MacOS the slash is used.

# %% [markdown]
# > ### Root Directory
# > - The ___root___ directory is thetop leveldirectory ona drive. Each drive has its own root directory, which is represented by the \character. You may see C:\ and Y:\

# %% [markdown]
# >### Absolute and Relative paths.
# > - An ___Absolute___ path will get to your destination, no matter where you start from.
# > - Eg : Internet URLs
# > - A ___Relative___ path will get there from where you are now, it is usually used everyday life.

# %% [markdown]
# > ### . and ..
# > - . means "current directory" and .. means "parent directory"

# %% [markdown]
# > ### Case - Sensitivety
# > - Windows filenames ___aren't case sensitive___.
# > - Linux filenames ___are case-sensitive___.
# > - macOS filenames ___are't case sensituve___, but are case-preserving, you can't create 2 files with same name.

# %% [markdown]
# > ### Reading from a text file.

# %%
jabber = open('jabberwocky.txt','r')

for line in jabber:
    print(line, end = '')

jabber.close()
# Out:
# 'Twas brillig, and the slithy toves
# Did gyre and gimble in the wabe;
# All mimsy were the borogoves,
# And the mome raths outgrabe.
#
# "Beware the Jabberwock, my son!
# The jaws that bite, the claws that catch!
# Beware the Jubjub bird, and shun
# The frumious Bandersnatch!"
#
# He took his vorpal sword in hand:
# Long time the manxome foe he soughtâ€”
# So rested he by the Tumtum tree,
# And stood awhile in thought.
#
# And as in uffish thought he stood,
# The Jabberwock, with eyes of flame,
# Came whiffling through the tulgey wood,
# And burbled as it came!
#
# One two! One two! And through and through
# The vorpal blade went snicker-snack!
# He left it dead, and with its head
# He went galumphing back.
#
# "And hast thou slain the Jabberwock?
# Come to my arms, my beamish boy!"
# "O frabjous day! Callooh! Callay!"
# He chortled in his joy.
#
# 'Twas brillig, and the slithy toves
# Did gyre and gimble in the wabe;
# All mimsy were the borogoves,
# And the mome raths outgrabe.
#
#     â€“ Lewis Carroll

# %%
filename = 'Jabberwocky.txt'
with open(filename,'r') as jabber:
    for line in jabber:
        print(line.rstrip())
    lines = jabber.readlines()
print(lines)
print(line[-1:])
for line in reversed(lines):
    print(line,end = '')
# Out:
# 'Twas brillig, and the slithy toves
# Did gyre and gimble in the wabe;
# All mimsy were the borogoves,
# And the mome raths outgrabe.
#
# "Beware the Jabberwock, my son!
# The jaws that bite, the claws that catch!
# Beware the Jubjub bird, and shun
# The frumious Bandersnatch!"
#
# He took his vorpal sword in hand:
# Long time the manxome foe he soughtâ€”
# So rested he by the Tumtum tree,
# And stood awhile in thought.
#
# And as in uffish thought he stood,
# The Jabberwock, with eyes of flame,
# Came whiffling through the tulgey wood,
# And burbled as it came!
#
# One two! One two! And through and through
# The vorpal blade went snicker-snack!
# He left it dead, and with its head
# He went galumphing back.
#
# "And hast thou slain the Jabberwock?
# Come to my arms, my beamish boy!"
# "O frabjous day! Callooh! Callay!"
# He chortled in his joy.
#
# 'Twas brillig, and the slithy toves
# Did gyre and gimble in the wabe;
# All mimsy were the borogoves,
# And the mome raths outgrabe.
#
#     â€“ Lewis Carroll
# []

# %%
def removeprefix(string: str, prefix: str) -> str:
    if string.startswith(prefix):
        return string[len(prefix):]
    else:
        return string[:]  # Return a copy of `string`.


def removesuffix(string: str, suffix: str) -> str:
    if suffix and string.endswith(suffix):  # suffix='' should not call string[:-0]
        return string[:-len(suffix)]
    else:
        return string[:]


filename = 'Jabberwocky.txt'
with open(filename) as poem:
    first = poem.readline().rstrip()

print(first)

chars = "' Twasebv"
# no_apostrophe = first.strip(chars)
# print(no_apostrophe)

for character in first:
    if character in chars:
        print(f'removing "{character}"')
    else:
        break

print('*' * 80)

for character in first[::-1]:  # process backwards
    if character in chars:
        print(f'removing "{character}"')
    else:
        break

print('*' * 80)

# twas_removed = first.removeprefix("'Twas")
twas_removed = removeprefix(first, "'Twas")
print(twas_removed)
# toves_removed = first.removesuffix('toves')
toves_removed = removesuffix(first, 'toves')
print(toves_removed)
# Out:
# 'Twas brillig, and the slithy toves
# removing "'"
# removing "T"
# removing "w"
# removing "a"
# removing "s"
# removing " "
# removing "b"
# ********************************************************************************
# removing "s"
# removing "e"
# removing "v"
# ********************************************************************************
#  brillig, and the slithy toves
# 'Twas brillig, and the slithy

# %% [markdown]
# > ### Remove Prefix and Remove Suffix

# %%
twas_removed = first.removeprefix('Twas')
twas_removed
# Out:
# "'Twas brillig, and the slithy toves"

# %%
toves_removed = first.removesuffix('toves')
toves_removed
# Out:
# "'Twas brillig, and the slithy "

# %% [markdown]
# > # Parsing
# > - Making sense of the data is called ___Parsing___. It means splitting it uplogically

# %%
input_filename = 'country_info.txt'
countries = {}
with open(input_filename) as country_file:
    
    country_file.readline()
    for row in country_file:
        data = row.strip('\n').split('|')
        country, capital, code, code3, dialing, timezone, currency = data
#         print(country, capital, code, code3, dialing, timezone, currency, sep = '\n\t')
        country_dict = {
            'name' : country,
            'capital' : capital,
            'country_code' : code,
            'cc3' : code3,
            'dialing_code' : dialing,
            'tiemzone' : timezone,
            'currency' : currency,
        }
        print(country_dict)
        countries[country.casefold()] = country_dict
print(countries)
# Out:
# {'name': 'Afghanistan', 'capital': 'Kabul', 'country_code': 'AF', 'cc3': 'AFG', 'dialing_code': '+93', 'tiemzone': 'UTC+04:30', 'currency': 'Afghan afghani'}
# {'name': 'Aland Islands', 'capital': 'Mariehamn', 'country_code': 'AX', 'cc3': 'ALA', 'dialing_code': '+358', 'tiemzone': 'UTC+02:00', 'currency': 'Euro'}
# {'name': 'Albania', 'capital': 'Tirana', 'country_code': 'AL', 'cc3': 'ALB', 'dialing_code': '+355', 'tiemzone': 'UTC+01:00', 'currency': 'Albanian lek'}
# {'name': 'Algeria', 'capital': 'Algiers', 'country_code': 'DZ', 'cc3': 'DZA', 'dialing_code': '+213', 'tiemzone': 'UTC', 'currency': 'Algerian dinar'}
# {'name': 'American Samoa', 'capital': 'Pago Pago', 'country_code': 'AS', 'cc3': 'ASM', 'dialing_code': '+1 684', 'tiemzone': 'UTC-11:00', 'currency': ''}
# {'name': 'Andorra', 'capital': 'Andorra la Vella', 'country_code': 'AD', 'cc3': 'AND', 'dialing_code': '+376', 'tiemzone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'Angola', 'capital': 'Luanda', 'country_code': 'AO', 'cc3': 'AGO', 'dialing_code': '+244', 'tiemzone': 'UTC+01:00', 'currency': 'Angolan kwanza'}
# {'name': 'Anguilla', 'capital': 'The Valley', 'country_code': 'AI', 'cc3': 'AIA', 'dialing_code': '+1 264', 'tiemzone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'name': 'Antarctica', 'capital': '', 'country_code': 'AQ', 'cc3': 'ATA', 'dialing_code': '', 'tiemzone': '', 'currency': ''}
# {'name': 'Antigua and Barbuda', 'capital': "St. John's", 'country_code': 'AG', 'cc3': 'ATG', 'dialing_code': '+1 268', 'tiemzone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'name': 'Argentina', 'capital': 'Buenos Aires', 'country_code': 'AR', 'cc3': 'ARG', 'dialing_code': '+54', 'tiemzone': 'UTC-03:00', 'currency': 'Argentine peso'}
# {'name': 'Armenia', 'capital': 'Yerevan', 'country_code': 'AM', 'cc3': 'ARM', 'dialing_code': '+374', 'tiemzone': 'UTC+04:00', 'currency': 'Armenian dram'}
# {'name': 'Aruba', 'capital': 'Oranjestad', 'country_code': 'AW', 'cc3': 'ABW', 'dialing_code': '+297', 'tiemzone': 'UTC-04:00', 'currency': 'Aruban florin'}
# {'name': 'Australia', 'capital': 'Canberra', 'country_code': 'AU', 'cc3': 'AUS', 'dialing_code': '+61', 'tiemzone': 'UTC+07:00 - UTC+10:00', 'currency': 'Australian dollar'}
# {'name': 'Austria', 'capital': 'Vienna', 'country_code': 'AT', 'cc3': 'AUT', 'dialing_code': '+43', 'tiemzone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'Azerbaijan', 'capital': 'Baku', 'country_code': 'AZ', 'cc3': 'AZE', 'dialing_code': '+994', 'tiemzone': 'UTC+04:00', 'currency': 'Azerbaijani manat'}
# {'name': 'Bahamas', 'capital': 'Nassau', 'country_code': 'BS', 'cc3': 'BHS', 'dialing_code': '+1 242', 'tiemzone': 'UTC-05:00', 'currency': 'Bahamian dollar'}
# {'name': 'Bahrain', 'capital': 'Manama', 'country_code': 'BH', 'cc3': 'BHR', 'dialing_code': '+973', 'tiemzone': 'UTC+03:00', 'currency': 'Bahraini dinar'}
# {'name': 'Bangladesh', 'capital': 'Dhaka', 'country_code': 'BD', 'cc3': 'BGD', 'dialing_code': '+880', 'tiemzone': 'UTC+06:00', 'currency': 'Bangladeshi taka'}
# {'name': 'Barbados', 'capital': 'Bridgetown', 'country_code': 'BB', 'cc3': 'BRB', 'dialing_code': '+1 246', 'tiemzone': 'UTC-04:00', 'currency': 'Barbadian dollar'}
# {'name': 'Belarus', 'capital': 'Minsk', 'country_code': 'BY', 'cc3': 'BLR', 'dialing_code': '+375', 'tiemzone': 'UTC+03:00', 'currency': 'Belarusian ruble'}
# {'name': 'Belgium', 'capital': 'Brussels', 'country_code': 'BE', 'cc3': 'BEL', 'dialing_code': '+32', 'tiemzone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'Belize', 'capital': 'Belmopan', 'country_code': 'BZ', 'cc3': 'BLZ', 'dialing_code': '+501', 'tiemzone': 'UTC-06:00', 'currency': 'Belize dollar'}
# {'name': 'Benin', 'capital': 'Porto-Novo', 'country_code': 'BJ', 'cc3': 'BEN', 'dialing_code': '+229', 'tiemzone': 'UTC+01:00', 'currency': 'West African CFA franc'}
# {'name': 'Bermuda', 'capital': 'Hamilton', 'country_code': 'BM', 'cc3': 'BMU', 'dialing_code': '+1 441', 'tiemzone': 'UTC-04:00', 'currency': 'Bermudian dollar'}
# {'name': 'Bhutan', 'capital': 'Thimphu', 'country_code': 'BT', 'cc3': 'BTN', 'dialing_code': '+975', 'tiemzone': 'UTC+05:30', 'currency': 'Bhutanese ngultrum'}
# {'name': 'Bolivia', 'capital': 'Sucre', 'country_code': 'BO', 'cc3': 'BOL', 'dialing_code': '+591', 'tiemzone': 'UTC-04:00', 'currency': 'Bolivian boliviano'}
# {'name': 'Bonaire', 'capital': 'Kralendijk', 'country_code': 'BQ', 'cc3': 'BES', 'dialing_code': '+599', 'tiemzone': 'UTC-04:00', 'currency': 'United States dollar'}
# {'name': 'Bosnia and Herzegovina', 'capital': 'Sarajevo', 'country_code': 'BA', 'cc3': 'BIH', 'dialing_code': '+387', 'tiemzone': 'UTC+01:00', 'currency': 'Bosnia and Herzegovina convertible mark'}
# {'name': 'Botswana', 'capital': 'Gaborone', 'country_code': 'BW', 'cc3': 'BWA', 'dialing_code': '+267', 'tiemzone': 'UTC+02:00', 'currency': 'Botswana pula'}
# {'name': 'Bouvet Island', 'capital': '', 'country_code': 'BV', 'cc3': 'BVT', 'dialing_code': '', 'tiemzone': 'UTC+01:00', 'currency': ''}
# {'name': 'Brazil', 'capital': 'BrasÃ\xadlia', 'country_code': 'BR', 'cc3': 'BRA', 'dialing_code': '+55', 'tiemzone': 'UTC-05:00 - UTC-03:00', 'currency': 'Brazilian real'}
# {'name': 'British Indian Ocean Territory', 'capital': 'Diego Garcia', 'country_code': 'IO', 'cc3': 'IOT', 'dialing_code': '+246', 'tiemzone': 'UTC+06', 'currency': 'United States dollar'}
# {'name': 'Brunei', 'capital': 'Bandar Seri Begawan', 'country_code': 'BN', 'cc3': 'BRN', 'dialing_code': '+673', 'tiemzone': 'UTC+08:00', 'currency': 'Brunei dollar'}
# {'name': 'Bulgaria', 'capital': 'Sofia', 'country_code': 'BG', 'cc3': 'BGR', 'dialing_code': '+359', 'tiemzone': 'UTC+02:00', 'currency': 'Bulgarian lev'}
# {'name': 'Burkina Faso', 'capital': 'Ouagadougou', 'country_code': 'BF', 'cc3': 'BFA', 'dialing_code': '+226', 'tiemzone': 'UTC', 'currency': 'West African CFA franc'}
# {'name': 'Burundi', 'capital': 'Bujumbura', 'country_code': 'BI', 'cc3': 'BDI', 'dialing_code': '+257', 'tiemzone': 'UTC+02:00', 'currency': 'Burundian franc'}
# {'name': 'Cambodia', 'capital': 'Phnom Penh', 'country_code': 'KH', 'cc3': 'KHM', 'dialing_code': '+855', 'tiemzone': 'UTC+07:00', 'currency': 'Cambodian riel'}
# {'name': 'Cameroon', 'capital': 'YaoundÃ©', 'country_code': 'CM', 'cc3': 'CMR', 'dialing_code': '+237', 'tiemzone': 'UTC+01:00', 'currency': 'Central African CFA franc'}
# {'name': 'Canada', 'capital': 'Ottawa', 'country_code': 'CA', 'cc3': 'CAN', 'dialing_code': '+1', 'tiemzone': 'UTC-08:00 - UTC-04:00', 'currency': 'Canadian dollar'}
# {'name': 'Cape Verde', 'capital': 'Praia', 'country_code': 'CV', 'cc3': 'CPV', 'dialing_code': '+238', 'tiemzone': 'UTC-01:00', 'currency': 'Cape Verdean escudo'}
# {'name': 'Cayman Islands', 'capital': 'George Town', 'country_code': 'KY', 'cc3': 'CYM', 'dialing_code': '+1 345', 'tiemzone': 'UTC-05:00', 'currency': 'Cayman Islands dollar'}
# {'name': 'Central African Republic', 'capital': 'Bangui', 'country_code': 'CF', 'cc3': 'CAF', 'dialing_code': '+236', 'tiemzone': 'UTC+01:00', 'currency': 'Central African CFA franc'}
# {'name': 'Chad', 'capital': "N'Djamena", 'country_code': 'TD', 'cc3': 'TCD', 'dialing_code': '+235', 'tiemzone': 'UTC+01:00', 'currency': 'Central African CFA franc'}
# {'name': 'Chile', 'capital': 'Santiago', 'country_code': 'CL', 'cc3': 'CHL', 'dialing_code': '+56', 'tiemzone': 'UTC-04:00', 'currency': 'Chilean peso'}
# {'name': 'China', 'capital': 'Beijing', 'country_code': 'CN', 'cc3': 'CHN', 'dialing_code': '+86', 'tiemzone': 'UTC+08:00', 'currency': 'Chinese yuan'}
# {'name': 'Christmas Island', 'capital': 'Flying Fish Cove', 'country_code': 'CX', 'cc3': 'CXR', 'dialing_code': '+61 8 9164', 'tiemzone': 'UTC+07', 'currency': 'Australian dollar'}
# {'name': 'Cocos (Keeling) Islands', 'capital': 'West Island', 'country_code': 'CC', 'cc3': 'CCK', 'dialing_code': '+61 8 9162', 'tiemzone': 'UTC+06:30', 'currency': 'Australian dollar'}
# {'name': 'Colombia', 'capital': 'BogotÃ¡', 'country_code': 'CO', 'cc3': 'COL', 'dialing_code': '+57', 'tiemzone': 'UTC-05:00', 'currency': 'Colombian peso'}
# {'name': 'Comoros', 'capital': 'Moroni', 'country_code': 'KM', 'cc3': 'COM', 'dialing_code': '+269', 'tiemzone': 'UTC+03:00', 'currency': 'Comorian franc'}
# {'name': 'Congo, Republic of the', 'capital': 'Brazzaville', 'country_code': 'CG', 'cc3': 'COG', 'dialing_code': '+242', 'tiemzone': 'UTC+01:00', 'currency': 'Central African CFA franc'}
# {'name': 'Congo, Democratic Republic of the', 'capital': 'Kinshasa', 'country_code': 'CD', 'cc3': 'COD', 'dialing_code': '+243', 'tiemzone': 'UTC+01:00 - UTC+02:00', 'currency': 'Congolese franc'}
# {'name': 'Cook Islands', 'capital': 'Avarua', 'country_code': 'CK', 'cc3': 'COK', 'dialing_code': '+682', 'tiemzone': 'UTC-10:00', 'currency': 'New Zealand dollar'}
# {'name': 'Costa Rica', 'capital': 'San JosÃ©', 'country_code': 'CR', 'cc3': 'CRI', 'dialing_code': '+506', 'tiemzone': 'UTC-06:00', 'currency': 'Costa Rican colÃ³n'}
# {'name': "CÃ´te d'Ivoire", 'capital': 'Yamoussoukro', 'country_code': 'CI', 'cc3': 'CIV', 'dialing_code': '+225', 'tiemzone': 'UTC', 'currency': 'West African CFA franc'}
# {'name': 'Croatia', 'capital': 'Zagreb', 'country_code': 'HR', 'cc3': 'HRV', 'dialing_code': '+385', 'tiemzone': 'UTC+01:00', 'currency': 'Croatian kuna'}
# {'name': 'Cuba', 'capital': 'Havana', 'country_code': 'CU', 'cc3': 'CUB', 'dialing_code': '+53', 'tiemzone': 'UTC-03:00', 'currency': 'Cuban convertible peso'}
# {'name': 'Curacao', 'capital': 'Willemstad', 'country_code': 'CW', 'cc3': 'CUW', 'dialing_code': '+599 9', 'tiemzone': 'UTC-04:00', 'currency': 'Netherlands Antillean guilder'}
# {'name': 'Cyprus', 'capital': 'Nicosia', 'country_code': 'CY', 'cc3': 'CYP', 'dialing_code': '+357', 'tiemzone': 'UTC+02:00', 'currency': 'Euro'}
# {'name': 'Czech Republic', 'capital': 'Prague', 'country_code': 'CZ', 'cc3': 'CZE', 'dialing_code': '+420', 'tiemzone': 'UTC+01:00', 'currency': 'Czech koruna'}
# {'name': 'Denmark', 'capital': 'Copenhagen', 'country_code': 'DK', 'cc3': 'DNK', 'dialing_code': '+45', 'tiemzone': 'UTC+01:00', 'currency': 'Danish krone'}
# {'name': 'Djibouti', 'capital': 'Djibouti', 'country_code': 'DJ', 'cc3': 'DJI', 'dialing_code': '+253', 'tiemzone': 'UTC+03:00', 'currency': 'Djiboutian franc'}
# {'name': 'Dominica', 'capital': 'Roseau', 'country_code': 'DM', 'cc3': 'DMA', 'dialing_code': '+1 767', 'tiemzone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'name': 'Dominican Republic', 'capital': 'Santo Domingo', 'country_code': 'DO', 'cc3': 'DOM', 'dialing_code': '+1 809/829/849', 'tiemzone': 'UTC-04:00', 'currency': 'Dominican peso'}
# {'name': 'East Timor', 'capital': 'Dili', 'country_code': 'TL', 'cc3': 'TLS', 'dialing_code': '+670', 'tiemzone': 'UTC+09', 'currency': 'United States dollar'}
# {'name': 'Ecuador', 'capital': 'Quito', 'country_code': 'EC', 'cc3': 'ECU', 'dialing_code': '+593', 'tiemzone': 'UTC-05:00', 'currency': 'United States dollar'}
# {'name': 'Egypt', 'capital': 'Cairo', 'country_code': 'EG', 'cc3': 'EGY', 'dialing_code': '+20', 'tiemzone': 'UTC+02:00', 'currency': 'Egyptian pound'}
# {'name': 'El Salvador', 'capital': 'San Salvador', 'country_code': 'SV', 'cc3': 'SLV', 'dialing_code': '+503', 'tiemzone': 'UTC-06:00', 'currency': 'Salvadoran colÃ³n'}
# {'name': 'Equatorial Guinea', 'capital': 'Malabo', 'country_code': 'GQ', 'cc3': 'GNQ', 'dialing_code': '+240', 'tiemzone': 'UTC+01:00', 'currency': 'Central African CFA franc'}
# {'name': 'Eritrea', 'capital': 'Asmara', 'country_code': 'ER', 'cc3': 'ERI', 'dialing_code': '+291', 'tiemzone': 'UTC+03:00', 'currency': 'Eritrean nakfa'}
# {'name': 'Estonia', 'capital': 'Tallinn', 'country_code': 'EE', 'cc3': 'EST', 'dialing_code': '+372', 'tiemzone': 'UTC+03:00', 'currency': 'Euro'}
# {'name': 'Ethiopia', 'capital': 'Addis Ababa', 'country_code': 'ET', 'cc3': 'ETH', 'dialing_code': '+251', 'tiemzone': 'UTC+03:00', 'currency': 'Ethiopian birr'}
# {'name': 'Falkland Islands (Malvinas)', 'capital': 'Stanley', 'country_code': 'FK', 'cc3': 'FLK', 'dialing_code': '+500', 'tiemzone': 'UTC-04:00', 'currency': 'Falkland Islands pound'}
# {'name': 'Faroe Islands', 'capital': 'TÃ³rshavn', 'country_code': 'FO', 'cc3': 'FRO', 'dialing_code': '+298', 'tiemzone': 'UTC', 'currency': 'Danish krone'}
# {'name': 'Fiji', 'capital': 'Suva', 'country_code': 'FJ', 'cc3': 'FJI', 'dialing_code': '+679', 'tiemzone': 'UTC+12:00', 'currency': 'Fijian dollar'}
# {'name': 'Finland', 'capital': 'Helsinki', 'country_code': 'FI', 'cc3': 'FIN', 'dialing_code': '+358', 'tiemzone': 'UTC+02:00', 'currency': 'Euro'}
# {'name': 'France', 'capital': 'Paris', 'country_code': 'FR', 'cc3': 'FRA', 'dialing_code': '+33', 'tiemzone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'French Guiana', 'capital': 'Cayenne', 'country_code': 'GF', 'cc3': 'GUF', 'dialing_code': '+594', 'tiemzone': 'UTC-01:00', 'currency': 'Euro'}
# {'name': 'French Polynesia', 'capital': 'Papeete', 'country_code': 'PF', 'cc3': 'PYF', 'dialing_code': '+689', 'tiemzone': 'UTC-10:00', 'currency': 'CFP franc'}
# {'name': 'French Southern Territories', 'capital': 'Port-aux-FranÃ§ais', 'country_code': 'TF', 'cc3': 'ATF', 'dialing_code': '', 'tiemzone': 'UTC+05:00', 'currency': 'Euro'}
# {'name': 'Gabon', 'capital': 'Libreville', 'country_code': 'GA', 'cc3': 'GAB', 'dialing_code': '+241', 'tiemzone': 'UTC+01:00', 'currency': 'Central African CFA franc'}
# {'name': 'Gambia', 'capital': 'Banjul', 'country_code': 'GM', 'cc3': 'GMB', 'dialing_code': '+220', 'tiemzone': 'UTC', 'currency': 'Gambian dalasi'}
# {'name': 'Georgia', 'capital': 'Tbilisi', 'country_code': 'GE', 'cc3': 'GEO', 'dialing_code': '+995', 'tiemzone': 'UTC+04:00', 'currency': 'Georgian lari'}
# {'name': 'Germany', 'capital': 'Berlin', 'country_code': 'DE', 'cc3': 'DEU', 'dialing_code': '+49', 'tiemzone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'Ghana', 'capital': 'Accra', 'country_code': 'GH', 'cc3': 'GHA', 'dialing_code': '+233', 'tiemzone': 'UTC', 'currency': 'Ghanaian cedi'}
# {'name': 'Gibraltar', 'capital': 'Gibraltar', 'country_code': 'GI', 'cc3': 'GIB', 'dialing_code': '+350', 'tiemzone': 'UTC+01:00', 'currency': 'Gibraltar pound'}
# {'name': 'Greece', 'capital': 'Athens', 'country_code': 'GR', 'cc3': 'GRC', 'dialing_code': '+30', 'tiemzone': 'UTC+02:00', 'currency': 'Euro'}
# {'name': 'Greenland', 'capital': 'Nuuk', 'country_code': 'GL', 'cc3': 'GRL', 'dialing_code': '+299', 'tiemzone': 'UTC-03:00', 'currency': 'Danish krone'}
# {'name': 'Grenada', 'capital': "St. George's", 'country_code': 'GD', 'cc3': 'GRD', 'dialing_code': '+1 473', 'tiemzone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'name': 'Guadeloupe', 'capital': 'Basse-Terre', 'country_code': 'GP', 'cc3': 'GLP', 'dialing_code': '+590', 'tiemzone': 'UTC-04:00', 'currency': 'Euro'}
# {'name': 'Guam', 'capital': 'HagÃ¥tÃ±a', 'country_code': 'GU', 'cc3': 'GUM', 'dialing_code': '+1 671', 'tiemzone': 'UTC+10:00', 'currency': 'United States dollar'}
# {'name': 'Guatemala', 'capital': 'Guatemala City', 'country_code': 'GT', 'cc3': 'GTM', 'dialing_code': '+502', 'tiemzone': 'UTC-06:00', 'currency': 'Guatemalan quetzal'}
# {'name': 'Guernsey', 'capital': 'St. Peter Port', 'country_code': 'GG', 'cc3': 'GGY', 'dialing_code': '+44 1481', 'tiemzone': 'UTC', 'currency': 'British pound'}
# {'name': 'Guinea', 'capital': 'Conakry', 'country_code': 'GN', 'cc3': 'GIN', 'dialing_code': '+224', 'tiemzone': 'UTC', 'currency': 'Guinean franc'}
# {'name': 'Guinea-Bissau', 'capital': 'Bissau', 'country_code': 'GW', 'cc3': 'GNB', 'dialing_code': '+245', 'tiemzone': 'UTC', 'currency': 'West African CFA franc'}
# {'name': 'Guyana', 'capital': 'Georgetown', 'country_code': 'GY', 'cc3': 'GUY', 'dialing_code': '+592', 'tiemzone': 'UTC-03:00', 'currency': 'Guyanese dollar'}
# {'name': 'Haiti', 'capital': 'Port-au-Prince', 'country_code': 'HT', 'cc3': 'HTI', 'dialing_code': '+509', 'tiemzone': 'UTC-05:00', 'currency': 'Haitian gourde'}
# {'name': 'Heard Island and McDonald Islands', 'capital': '', 'country_code': 'HM', 'cc3': 'HMD', 'dialing_code': '', 'tiemzone': 'UTC+05', 'currency': ''}
# {'name': 'Honduras', 'capital': 'Tegucigalpa', 'country_code': 'HN', 'cc3': 'HND', 'dialing_code': '+504', 'tiemzone': 'UTC-06:00', 'currency': 'Honduran lempira'}
# {'name': 'Hong Kong', 'capital': '', 'country_code': 'HK', 'cc3': 'HKG', 'dialing_code': '+852', 'tiemzone': 'UTC+08:00', 'currency': 'Hong Kong dollar'}
# {'name': 'Hungary', 'capital': 'Budapest', 'country_code': 'HU', 'cc3': 'HUN', 'dialing_code': '+36', 'tiemzone': 'UTC+01:00', 'currency': 'Hungarian forint'}
# {'name': 'Iceland', 'capital': 'ReykjavÃ\xadk', 'country_code': 'IS', 'cc3': 'ISL', 'dialing_code': '+354', 'tiemzone': 'UTC', 'currency': 'Icelandic krÃ³na'}
# {'name': 'India', 'capital': 'New Delhi', 'country_code': 'IN', 'cc3': 'IND', 'dialing_code': '+91', 'tiemzone': 'UTC+05:30', 'currency': 'Indian rupee'}
# {'name': 'Indonesia', 'capital': 'Jakarta', 'country_code': 'ID', 'cc3': 'IDN', 'dialing_code': '+62', 'tiemzone': 'UTC+07:00 - UTC+09:00', 'currency': 'Indonesian rupiah'}
# {'name': 'Iran', 'capital': 'Tehran', 'country_code': 'IR', 'cc3': 'IRN', 'dialing_code': '+98', 'tiemzone': 'UTC+03:30', 'currency': 'Iranian rial'}
# {'name': 'Iraq', 'capital': 'Baghdad', 'country_code': 'IQ', 'cc3': 'IRQ', 'dialing_code': '+964', 'tiemzone': 'UTC+03:00', 'currency': 'Iraqi dinar'}
# {'name': 'Ireland', 'capital': 'Dublin', 'country_code': 'IE', 'cc3': 'IRL', 'dialing_code': '+353', 'tiemzone': 'UTC', 'currency': 'Euro'}
# {'name': 'Isle of Man', 'capital': 'Douglas', 'country_code': 'IM', 'cc3': 'IMN', 'dialing_code': '+44 1624', 'tiemzone': 'UTC', 'currency': 'British pound'}
# {'name': 'Israel', 'capital': 'Jerusalem', 'country_code': 'IL', 'cc3': 'ISR', 'dialing_code': '+972', 'tiemzone': 'UTC+02:00', 'currency': 'Israeli new shekel'}
# {'name': 'Italy', 'capital': 'Rome', 'country_code': 'IT', 'cc3': 'ITA', 'dialing_code': '+39', 'tiemzone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'Jamaica', 'capital': 'Kingston', 'country_code': 'JM', 'cc3': 'JAM', 'dialing_code': '+1 876', 'tiemzone': 'UTC-05:00', 'currency': 'Jamaican dollar'}
# {'name': 'Japan', 'capital': 'Tokyo', 'country_code': 'JP', 'cc3': 'JPN', 'dialing_code': '+81', 'tiemzone': 'UTC+09:00', 'currency': 'Japanese yen'}
# {'name': 'Jersey', 'capital': 'St. Helier', 'country_code': 'JE', 'cc3': 'JEY', 'dialing_code': '+44 1534', 'tiemzone': 'UTC', 'currency': 'British pound'}
# {'name': 'Jordan', 'capital': 'Amman', 'country_code': 'JO', 'cc3': 'JOR', 'dialing_code': '+962', 'tiemzone': 'UTC+02:00', 'currency': 'Jordanian dinar'}
# {'name': 'Kazakhstan', 'capital': 'Astana', 'country_code': 'KZ', 'cc3': 'KAZ', 'dialing_code': '+7 6xx/7xx', 'tiemzone': 'UTC+06:00', 'currency': 'Kazakhstani tenge'}
# {'name': 'Kenya', 'capital': 'Nairobi', 'country_code': 'KE', 'cc3': 'KEN', 'dialing_code': '+254', 'tiemzone': 'UTC+03:00', 'currency': 'Kenyan shilling'}
# {'name': 'Kiribati', 'capital': 'Tarawa', 'country_code': 'KI', 'cc3': 'KIR', 'dialing_code': '+686', 'tiemzone': 'UTC+12:00', 'currency': 'Australian dollar'}
# {'name': 'Kuwait', 'capital': 'Kuwait City', 'country_code': 'KW', 'cc3': 'KWT', 'dialing_code': '+965', 'tiemzone': 'UTC+03:00', 'currency': 'Kuwaiti dinar'}
# {'name': 'Kyrgyzstan', 'capital': 'Bishkek', 'country_code': 'KG', 'cc3': 'KGZ', 'dialing_code': '+996', 'tiemzone': 'UTC+06:00', 'currency': 'Kyrgyzstani som'}
# {'name': 'Laos', 'capital': 'Vientiane', 'country_code': 'LA', 'cc3': 'LAO', 'dialing_code': '+856', 'tiemzone': 'UTC+07:00', 'currency': 'Lao kip'}
# {'name': 'Latvia', 'capital': 'Riga', 'country_code': 'LV', 'cc3': 'LVA', 'dialing_code': '+371', 'tiemzone': 'UTC+03:00', 'currency': 'Latvian lats'}
# {'name': 'Lebanon', 'capital': 'Beirut', 'country_code': 'LB', 'cc3': 'LBN', 'dialing_code': '+961', 'tiemzone': 'UTC+02:00', 'currency': 'Lebanese pound'}
# {'name': 'Lesotho', 'capital': 'Maseru', 'country_code': 'LS', 'cc3': 'LSO', 'dialing_code': '+266', 'tiemzone': 'UTC+02:00', 'currency': 'Lesotho loti'}
# {'name': 'Liberia', 'capital': 'Monrovia', 'country_code': 'LR', 'cc3': 'LBR', 'dialing_code': '+231', 'tiemzone': 'UTC', 'currency': 'Liberian dollar'}
# {'name': 'Libya', 'capital': 'Tripoli', 'country_code': 'LY', 'cc3': 'LBY', 'dialing_code': '+218', 'tiemzone': 'UTC+02:00', 'currency': 'Libyan dinar'}
# {'name': 'Liechtenstein', 'capital': 'Vaduz', 'country_code': 'LI', 'cc3': 'LIE', 'dialing_code': '+423', 'tiemzone': 'UTC+01:00', 'currency': 'Swiss franc'}
# {'name': 'Lithuania', 'capital': 'Vilnius', 'country_code': 'LT', 'cc3': 'LTU', 'dialing_code': '+370', 'tiemzone': 'UTC+02:00', 'currency': 'Lithuanian litas'}
# {'name': 'Luxembourg', 'capital': 'Luxembourg', 'country_code': 'LU', 'cc3': 'LUX', 'dialing_code': '+352', 'tiemzone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'Macau', 'capital': '', 'country_code': 'MO', 'cc3': 'MAC', 'dialing_code': '+853', 'tiemzone': 'UTC+08:00', 'currency': 'Macanese pataca'}
# {'name': 'Macedonia', 'capital': 'Skopje', 'country_code': 'MK', 'cc3': 'MKD', 'dialing_code': '+389', 'tiemzone': 'UTC+01:00', 'currency': 'Macedonian denar'}
# {'name': 'Madagascar', 'capital': 'Antananarivo', 'country_code': 'MG', 'cc3': 'MDG', 'dialing_code': '+261', 'tiemzone': 'UTC+03:00', 'currency': 'Malagasy ariary'}
# {'name': 'Malawi', 'capital': 'Lilongwe', 'country_code': 'MW', 'cc3': 'MWI', 'dialing_code': '+265', 'tiemzone': 'UTC+02:00', 'currency': 'Malawian kwacha'}
# {'name': 'Malaysia', 'capital': 'Kuala Lumpur', 'country_code': 'MY', 'cc3': 'MYS', 'dialing_code': '+60', 'tiemzone': 'UTC+08:00', 'currency': 'Malaysian ringgit'}
# {'name': 'Maldives', 'capital': 'MalÃ©', 'country_code': 'MV', 'cc3': 'MDV', 'dialing_code': '+960', 'tiemzone': 'UTC+05:00', 'currency': 'Maldivian rufiyaa'}
# {'name': 'Mali', 'capital': 'Bamako', 'country_code': 'ML', 'cc3': 'MLI', 'dialing_code': '+223', 'tiemzone': 'UTC', 'currency': 'West African CFA franc'}
# {'name': 'Malta', 'capital': 'Valletta', 'country_code': 'MT', 'cc3': 'MLT', 'dialing_code': '+356', 'tiemzone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'Marshall Islands', 'capital': 'Majuro', 'country_code': 'MH', 'cc3': 'MHL', 'dialing_code': '+692', 'tiemzone': 'UTC+10:00', 'currency': 'United States dollar'}
# {'name': 'Martinique', 'capital': 'Fort-de-France', 'country_code': 'MQ', 'cc3': 'MTQ', 'dialing_code': '+596', 'tiemzone': 'UTC-04:00', 'currency': 'Euro'}
# {'name': 'Mauritania', 'capital': 'Nouakchott', 'country_code': 'MR', 'cc3': 'MRT', 'dialing_code': '+222', 'tiemzone': 'UTC', 'currency': 'Mauritanian ouguiya'}
# {'name': 'Mauritius', 'capital': 'Port Louis', 'country_code': 'MU', 'cc3': 'MUS', 'dialing_code': '+230', 'tiemzone': 'UTC+04:00', 'currency': 'Mauritian rupee'}
# {'name': 'Mayotte', 'capital': 'Mamoudzou', 'country_code': 'YT', 'cc3': 'MYT', 'dialing_code': '+262 269/639', 'tiemzone': 'UTC+03:00', 'currency': 'Euro'}
# {'name': 'Mexico', 'capital': 'Mexico City', 'country_code': 'MX', 'cc3': 'MEX', 'dialing_code': '+52', 'tiemzone': 'UTC-08:00 - UTC-06:00', 'currency': 'Mexican peso'}
# {'name': 'Micronesia', 'capital': 'Palikir', 'country_code': 'FM', 'cc3': 'FSM', 'dialing_code': '+691', 'tiemzone': 'UTC+10:00', 'currency': 'Micronesian dollar'}
# {'name': 'Moldova', 'capital': 'Chisinau', 'country_code': 'MD', 'cc3': 'MDA', 'dialing_code': '+373', 'tiemzone': 'UTC+03:00', 'currency': 'Moldovan leu'}
# {'name': 'Monaco', 'capital': 'Monaco', 'country_code': 'MC', 'cc3': 'MCO', 'dialing_code': '+377', 'tiemzone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'Mongolia', 'capital': 'Ulaanbaatar', 'country_code': 'MN', 'cc3': 'MNG', 'dialing_code': '+976', 'tiemzone': 'UTC+08:00', 'currency': 'Mongolian tÃ¶grÃ¶g'}
# {'name': 'Montenegro', 'capital': 'Podgorica', 'country_code': 'ME', 'cc3': 'MNE', 'dialing_code': '+382', 'tiemzone': 'UTC+01', 'currency': 'Euro'}
# {'name': 'Montserrat', 'capital': 'Plymouth', 'country_code': 'MS', 'cc3': 'MSR', 'dialing_code': '+1 664', 'tiemzone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'name': 'Morocco', 'capital': 'Rabat', 'country_code': 'MA', 'cc3': 'MAR', 'dialing_code': '+212', 'tiemzone': 'UTC', 'currency': 'Moroccan dirham'}
# {'name': 'Mozambique', 'capital': 'Maputo', 'country_code': 'MZ', 'cc3': 'MOZ', 'dialing_code': '+258', 'tiemzone': 'UTC+02:00', 'currency': 'Mozambican metical'}
# {'name': 'Myanmar (Burma)', 'capital': 'Naypyidaw', 'country_code': 'MM', 'cc3': 'MMR', 'dialing_code': '+95', 'tiemzone': 'UTC+06:30', 'currency': 'Myanma kyat'}
# {'name': 'Namibia', 'capital': 'Windhoek', 'country_code': 'NA', 'cc3': 'NAM', 'dialing_code': '+264', 'tiemzone': 'UTC+02:00', 'currency': 'Namibian dollar'}
# {'name': 'Nauru', 'capital': 'Yaren', 'country_code': 'NR', 'cc3': 'NRU', 'dialing_code': '+674', 'tiemzone': 'UTC+12:00', 'currency': 'Australian dollar'}
# {'name': 'Nepal', 'capital': 'Kathmandu', 'country_code': 'NP', 'cc3': 'NPL', 'dialing_code': '+977', 'tiemzone': 'UTC+05:30', 'currency': 'Nepalese rupee'}
# {'name': 'Netherlands', 'capital': 'Amsterdam', 'country_code': 'NL', 'cc3': 'NLD', 'dialing_code': '+31', 'tiemzone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'New Caledonia', 'capital': 'NoumÃ©a', 'country_code': 'NC', 'cc3': 'NCL', 'dialing_code': '+687', 'tiemzone': 'UTC+11:00', 'currency': 'CFP franc'}
# {'name': 'New Zealand', 'capital': 'Wellington', 'country_code': 'NZ', 'cc3': 'NZL', 'dialing_code': '+64', 'tiemzone': 'UTC+12:00', 'currency': 'New Zealand dollar'}
# {'name': 'Nicaragua', 'capital': 'Managua', 'country_code': 'NI', 'cc3': 'NIC', 'dialing_code': '+505', 'tiemzone': 'UTC-06:00', 'currency': 'Nicaraguan cÃ³rdoba'}
# {'name': 'Niger', 'capital': 'Niamey', 'country_code': 'NE', 'cc3': 'NER', 'dialing_code': '+227', 'tiemzone': 'UTC+01:00', 'currency': 'West African CFA franc'}
# {'name': 'Nigeria', 'capital': 'Abuja', 'country_code': 'NG', 'cc3': 'NGA', 'dialing_code': '+234', 'tiemzone': 'UTC+01:00', 'currency': 'Nigerian naira'}
# {'name': 'Niue', 'capital': 'Alofi', 'country_code': 'NU', 'cc3': 'NIU', 'dialing_code': '+683', 'tiemzone': 'UTC-11:00', 'currency': 'New Zealand dollar'}
# {'name': 'Norfolk Island', 'capital': 'Kingston', 'country_code': 'NF', 'cc3': 'NFK', 'dialing_code': '+672 3', 'tiemzone': 'UTC+11:30', 'currency': 'Australian dollar'}
# {'name': 'North Korea', 'capital': 'Pyongyang', 'country_code': 'KP', 'cc3': 'PRK', 'dialing_code': '+850', 'tiemzone': 'UTC+09:00', 'currency': 'North Korean won'}
# {'name': 'Northern Mariana Islands', 'capital': 'Saipan', 'country_code': 'MP', 'cc3': 'MNP', 'dialing_code': '+1 670', 'tiemzone': 'UTC+10:00', 'currency': 'United States dollar'}
# {'name': 'Norway', 'capital': 'Oslo', 'country_code': 'NO', 'cc3': 'NOR', 'dialing_code': '+47', 'tiemzone': 'UTC+01:00', 'currency': 'Norwegian krone'}
# {'name': 'Oman', 'capital': 'Muscat', 'country_code': 'OM', 'cc3': 'OMN', 'dialing_code': '+968', 'tiemzone': 'UTC+04:00', 'currency': 'Omani rial'}
# {'name': 'Pakistan', 'capital': 'Islamabad', 'country_code': 'PK', 'cc3': 'PAK', 'dialing_code': '+92', 'tiemzone': 'UTC+05:00', 'currency': 'Pakistani rupee'}
# {'name': 'Palau', 'capital': 'Ngerulmud', 'country_code': 'PW', 'cc3': 'PLW', 'dialing_code': '+680', 'tiemzone': 'UTC+09:00', 'currency': 'Palauan dollar'}
# {'name': 'Panama', 'capital': 'Panama City', 'country_code': 'PA', 'cc3': 'PAN', 'dialing_code': '+507', 'tiemzone': 'UTC-05:00', 'currency': 'Panamanian balboa'}
# {'name': 'Papua New Guinea', 'capital': 'Port Moresby', 'country_code': 'PG', 'cc3': 'PNG', 'dialing_code': '+675', 'tiemzone': 'UTC+10:00', 'currency': 'Papua New Guinean kina'}
# {'name': 'Paraguay', 'capital': 'AsunciÃ³n', 'country_code': 'PY', 'cc3': 'PRY', 'dialing_code': '+595', 'tiemzone': 'UTC-04:00', 'currency': 'Paraguayan guaranÃ\xad'}
# {'name': 'Peru', 'capital': 'Lima', 'country_code': 'PE', 'cc3': 'PER', 'dialing_code': '+51', 'tiemzone': 'UTC-05:00', 'currency': 'Peruvian nuevo sol'}
# {'name': 'Philippines', 'capital': 'Manila', 'country_code': 'PH', 'cc3': 'PHL', 'dialing_code': '+63', 'tiemzone': 'UTC+08:00', 'currency': 'Philippine peso'}
# {'name': 'Pitcairn', 'capital': 'Adamstown', 'country_code': 'PN', 'cc3': 'PCN', 'dialing_code': '+872', 'tiemzone': 'UTC-08', 'currency': 'New Zealand dollar'}
# {'name': 'Poland', 'capital': 'Warsaw', 'country_code': 'PL', 'cc3': 'POL', 'dialing_code': '+48', 'tiemzone': 'UTC+01:00', 'currency': 'Polish zÅ‚oty'}
# {'name': 'Portugal', 'capital': 'Lisbon', 'country_code': 'PT', 'cc3': 'PRT', 'dialing_code': '+351', 'tiemzone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'Puerto Rico', 'capital': 'San Juan', 'country_code': 'PR', 'cc3': 'PRI', 'dialing_code': '+1 787/939', 'tiemzone': 'UTC-04:00', 'currency': 'United States dollar'}
# {'name': 'Qatar', 'capital': 'Doha', 'country_code': 'QA', 'cc3': 'QAT', 'dialing_code': '+974', 'tiemzone': 'UTC+03:00', 'currency': 'Qatari riyal'}
# {'name': 'Reunion', 'capital': '', 'country_code': 'RE', 'cc3': 'REU', 'dialing_code': '+262', 'tiemzone': 'UTC+04:00', 'currency': 'Euro'}
# {'name': 'Romania', 'capital': 'Bucharest', 'country_code': 'RO', 'cc3': 'ROU', 'dialing_code': '+40', 'tiemzone': 'UTC+02:00', 'currency': 'Romanian leu'}
# {'name': 'Russia', 'capital': 'Moscow', 'country_code': 'RU', 'cc3': 'RUS', 'dialing_code': '+7', 'tiemzone': 'UTC+03:00', 'currency': 'Russian ruble'}
# {'name': 'Rwanda', 'capital': 'Kigali', 'country_code': 'RW', 'cc3': 'RWA', 'dialing_code': '+250', 'tiemzone': 'UTC+02:00', 'currency': 'Rwandan franc'}
# {'name': 'Saint Barthelemy', 'capital': 'Gustavia', 'country_code': 'BL', 'cc3': 'BLM', 'dialing_code': '+590', 'tiemzone': 'UTC-04', 'currency': 'Euro'}
# {'name': 'Saint Helena', 'capital': 'Jamestown', 'country_code': 'SH', 'cc3': 'SHN', 'dialing_code': '+290', 'tiemzone': 'UTC', 'currency': 'Saint Helena pound'}
# {'name': 'Saint Kitts and Nevis', 'capital': 'Basseterre', 'country_code': 'KN', 'cc3': 'KNA', 'dialing_code': '+1 869', 'tiemzone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'name': 'Saint Lucia', 'capital': 'Castries', 'country_code': 'LC', 'cc3': 'LCA', 'dialing_code': '+1 758', 'tiemzone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'name': 'Saint Martin', 'capital': 'Marigot', 'country_code': 'MF', 'cc3': 'MAF', 'dialing_code': '+590', 'tiemzone': 'UTC-04', 'currency': 'Euro'}
# {'name': 'Saint Pierre and Miquelon', 'capital': 'St. Pierre', 'country_code': 'PM', 'cc3': 'SPM', 'dialing_code': '+508', 'tiemzone': 'UTC-03', 'currency': 'Euro'}
# {'name': 'Saint Vincent and the Grenadines', 'capital': 'Kingstown', 'country_code': 'VC', 'cc3': 'VCT', 'dialing_code': '+1 784', 'tiemzone': 'UTC-04', 'currency': 'East Caribbean dollar'}
# {'name': 'Samoa', 'capital': 'Apia', 'country_code': 'WS', 'cc3': 'WSM', 'dialing_code': '+685', 'tiemzone': 'UTC-11:00', 'currency': 'Samoan tala'}
# {'name': 'San Marino', 'capital': 'San Marino', 'country_code': 'SM', 'cc3': 'SMR', 'dialing_code': '+378', 'tiemzone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'Sao Tome and PrÃ\xadncipe', 'capital': 'SÃ£o TomÃ©', 'country_code': 'ST', 'cc3': 'STP', 'dialing_code': '+239', 'tiemzone': 'UTC', 'currency': 'SÃ£o TomÃ© and PrÃ\xadncipe dobra'}
# {'name': 'Saudi Arabia', 'capital': 'Riyadh', 'country_code': 'SA', 'cc3': 'SAU', 'dialing_code': '+966', 'tiemzone': 'UTC+03:00', 'currency': 'Saudi riyal'}
# {'name': 'Senegal', 'capital': 'Dakar', 'country_code': 'SN', 'cc3': 'SEN', 'dialing_code': '+221', 'tiemzone': 'UTC', 'currency': 'West African CFA franc'}
# {'name': 'Serbia', 'capital': 'Belgrade', 'country_code': 'RS', 'cc3': 'SRB', 'dialing_code': '+381', 'tiemzone': 'UTC+01:00', 'currency': 'Serbian dinar'}
# {'name': 'Seychelles', 'capital': 'Victoria', 'country_code': 'SC', 'cc3': 'SYC', 'dialing_code': '+248', 'tiemzone': 'UTC+04:00', 'currency': 'Seychellois rupee'}
# {'name': 'Sierra Leone', 'capital': 'Freetown', 'country_code': 'SL', 'cc3': 'SLE', 'dialing_code': '+232', 'tiemzone': 'UTC', 'currency': 'Sierra Leonean leone'}
# {'name': 'Singapore', 'capital': 'Singapore', 'country_code': 'SG', 'cc3': 'SGP', 'dialing_code': '+65', 'tiemzone': 'UTC+08:00', 'currency': 'Brunei dollar'}
# {'name': 'Sint Maarten', 'capital': 'Philipsburg', 'country_code': 'SX', 'cc3': 'SXM', 'dialing_code': '+599 5', 'tiemzone': 'UTC-04:00', 'currency': 'Netherlands Antillean guilder'}
# {'name': 'Slovakia', 'capital': 'Bratislava', 'country_code': 'SK', 'cc3': 'SVK', 'dialing_code': '+421', 'tiemzone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'Slovenia', 'capital': 'Ljubljana', 'country_code': 'SI', 'cc3': 'SVN', 'dialing_code': '+386', 'tiemzone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'Solomon Islands', 'capital': 'Honiara', 'country_code': 'SB', 'cc3': 'SLB', 'dialing_code': '+677', 'tiemzone': 'UTC+11:00', 'currency': 'Solomon Islands dollar'}
# {'name': 'Somalia', 'capital': 'Mogadishu', 'country_code': 'SO', 'cc3': 'SOM', 'dialing_code': '+252', 'tiemzone': 'UTC+03:00', 'currency': 'Somali shilling'}
# {'name': 'South Africa', 'capital': 'Pretoria', 'country_code': 'ZA', 'cc3': 'ZAF', 'dialing_code': '+27', 'tiemzone': 'UTC+02:00', 'currency': 'South African rand'}
# {'name': 'South Georgia and the South Sandwich Islands', 'capital': 'Grytviken', 'country_code': 'GS', 'cc3': 'SGS', 'dialing_code': '', 'tiemzone': 'UTC-02', 'currency': 'British pound'}
# {'name': 'South Korea', 'capital': 'Seoul', 'country_code': 'KR', 'cc3': 'KOR', 'dialing_code': '+82', 'tiemzone': 'UTC+09:00', 'currency': 'South Korean won'}
# {'name': 'Spain', 'capital': 'Madrid', 'country_code': 'ES', 'cc3': 'ESP', 'dialing_code': '+34', 'tiemzone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'Sri Lanka', 'capital': 'Sri Jayawardenapura Kotte', 'country_code': 'LK', 'cc3': 'LKA', 'dialing_code': '+94', 'tiemzone': 'UTC+05:30', 'currency': 'Sri Lankan rupee'}
# {'name': 'Sudan', 'capital': 'Khartoum', 'country_code': 'SD', 'cc3': 'SDN', 'dialing_code': '+249', 'tiemzone': 'UTC+02:00', 'currency': 'Sudanese pound'}
# {'name': 'Suriname', 'capital': 'Paramaribo', 'country_code': 'SR', 'cc3': 'SUR', 'dialing_code': '+597', 'tiemzone': 'UTC-03:30', 'currency': 'Surinamese dollar'}
# {'name': 'Svalbard and Jan Mayen', 'capital': '', 'country_code': 'SJ', 'cc3': 'SJM', 'dialing_code': '+47', 'tiemzone': 'UTC+01:00', 'currency': 'Norwegian krone'}
# {'name': 'Swaziland', 'capital': 'Mbabane', 'country_code': 'SZ', 'cc3': 'SWZ', 'dialing_code': '+268', 'tiemzone': 'UTC+02:00', 'currency': 'Swazi lilangeni'}
# {'name': 'Sweden', 'capital': 'Stockholm', 'country_code': 'SE', 'cc3': 'SWE', 'dialing_code': '+46', 'tiemzone': 'UTC+01:00', 'currency': 'Swedish krona'}
# {'name': 'Switzerland', 'capital': 'Bern', 'country_code': 'CH', 'cc3': 'CHE', 'dialing_code': '+41', 'tiemzone': 'UTC+01:00', 'currency': 'Swiss franc'}
# {'name': 'Syrian Arab Republic', 'capital': 'Damascus', 'country_code': 'SY', 'cc3': 'SYR', 'dialing_code': '+963', 'tiemzone': 'UTC+02:00', 'currency': 'Syrian pound'}
# {'name': 'Taiwan', 'capital': 'Taipei', 'country_code': 'TW', 'cc3': 'TWN', 'dialing_code': '+886', 'tiemzone': 'UTC+08:00', 'currency': 'New Taiwan dollar'}
# {'name': 'Tajikistan', 'capital': 'Dushanbe', 'country_code': 'TJ', 'cc3': 'TJK', 'dialing_code': '+992', 'tiemzone': 'UTC+06:00', 'currency': 'Tajikistani somoni'}
# {'name': 'Tanzania', 'capital': 'Dodoma', 'country_code': 'TZ', 'cc3': 'TZA', 'dialing_code': '+255', 'tiemzone': 'UTC+03:00', 'currency': 'Tanzanian shilling'}
# {'name': 'Thailand', 'capital': 'Bangkok', 'country_code': 'TH', 'cc3': 'THA', 'dialing_code': '+66', 'tiemzone': 'UTC+07:00', 'currency': 'Thai baht'}
# {'name': 'Togo', 'capital': 'LomÃ©', 'country_code': 'TG', 'cc3': 'TGO', 'dialing_code': '+228', 'tiemzone': 'UTC', 'currency': 'West African CFA franc'}
# {'name': 'Tokelau', 'capital': 'Rotates annually', 'country_code': 'TK', 'cc3': 'TKL', 'dialing_code': '+690', 'tiemzone': 'UTC-10', 'currency': 'New Zealand dollar'}
# {'name': 'Tonga', 'capital': 'Nuku', 'country_code': 'TO', 'cc3': 'TON', 'dialing_code': '+676', 'tiemzone': 'UTC+13:00', 'currency': 'Tongan paÊ»anga'}
# {'name': 'Trinidad and Tobago', 'capital': 'Port of Spain', 'country_code': 'TT', 'cc3': 'TTO', 'dialing_code': '+1 868', 'tiemzone': 'UTC-04:00', 'currency': 'Trinidad and Tobago dollar'}
# {'name': 'Tunisia', 'capital': 'Tunis', 'country_code': 'TN', 'cc3': 'TUN', 'dialing_code': '+216', 'tiemzone': 'UTC+01:00', 'currency': 'Tunisian dinar'}
# {'name': 'Turkey', 'capital': 'Ankara', 'country_code': 'TR', 'cc3': 'TUR', 'dialing_code': '+90', 'tiemzone': 'UTC+02:00', 'currency': 'Turkish lira'}
# {'name': 'Turkmenistan', 'capital': 'Ashgabat', 'country_code': 'TM', 'cc3': 'TKM', 'dialing_code': '+993', 'tiemzone': 'UTC+05:00', 'currency': 'Turkmenistani manat'}
# {'name': 'Turks and Caicos Islands', 'capital': 'Cockburn Town', 'country_code': 'TC', 'cc3': 'TCA', 'dialing_code': '+1 649', 'tiemzone': 'UTC-05:00', 'currency': 'United States dollar'}
# {'name': 'Tuvalu', 'capital': 'Funafuti', 'country_code': 'TV', 'cc3': 'TUV', 'dialing_code': '+688', 'tiemzone': 'UTC+12:00', 'currency': 'Australian dollar'}
# {'name': 'Uganda', 'capital': 'Kampala', 'country_code': 'UG', 'cc3': 'UGA', 'dialing_code': '+256', 'tiemzone': 'UTC+03:00', 'currency': 'Ugandan shilling'}
# {'name': 'Ukraine', 'capital': 'Kyiv', 'country_code': 'UA', 'cc3': 'UKR', 'dialing_code': '+380', 'tiemzone': 'UTC+03:00', 'currency': 'Ukrainian hryvnia'}
# {'name': 'United Arab Emirates', 'capital': 'Abu Dhabi', 'country_code': 'AE', 'cc3': 'ARE', 'dialing_code': '+971', 'tiemzone': 'UTC+04:00', 'currency': 'United Arab Emirates dirham'}
# {'name': 'United Kingdom', 'capital': 'London', 'country_code': 'GB', 'cc3': 'GBR', 'dialing_code': '+44', 'tiemzone': 'UTC', 'currency': 'British pound'}
# {'name': 'United States', 'capital': 'Washington D.C.', 'country_code': 'US', 'cc3': 'USA', 'dialing_code': '+1', 'tiemzone': 'UTC-11:00 - UTC-05:00', 'currency': 'United States dollar'}
# {'name': 'United States Minor Outlying Islands', 'capital': '', 'country_code': 'UM', 'cc3': 'UMI', 'dialing_code': '+1', 'tiemzone': '', 'currency': 'United States dollar'}
# {'name': 'Uruguay', 'capital': 'Montevideo', 'country_code': 'UY', 'cc3': 'URY', 'dialing_code': '+598', 'tiemzone': 'UTC-03:00', 'currency': 'Uruguayan peso'}
# {'name': 'Uzbekistan', 'capital': 'Tashkent', 'country_code': 'UZ', 'cc3': 'UZB', 'dialing_code': '+998', 'tiemzone': 'UTC+06:00', 'currency': 'Uzbekistani som'}
# {'name': 'Vanuatu', 'capital': 'Port Vila', 'country_code': 'VU', 'cc3': 'VUT', 'dialing_code': '+678', 'tiemzone': 'UTC+11:00', 'currency': 'Vanuatu vatu'}
# {'name': 'Vatican City', 'capital': 'Vatican City', 'country_code': 'VA', 'cc3': 'VAT', 'dialing_code': '+39 06 698', 'tiemzone': 'UTC+01', 'currency': 'Euro'}
# {'name': 'Venezuela', 'capital': 'Caracas', 'country_code': 'VE', 'cc3': 'VEN', 'dialing_code': '+58', 'tiemzone': 'UTC-04:00', 'currency': 'Venezuelan bolÃ\xadvar'}
# {'name': 'Vietnam', 'capital': 'Hanoi', 'country_code': 'VN', 'cc3': 'VNM', 'dialing_code': '+84', 'tiemzone': 'UTC+07:00', 'currency': 'Vietnamese Ä‘á»“ng'}
# {'name': 'Virgin Islands', 'capital': 'Road Town', 'country_code': 'VG', 'cc3': 'VGB', 'dialing_code': '+1 284', 'tiemzone': 'UTC-04', 'currency': 'British Virgin Islands dollar'}
# {'name': 'Virgin Islands of the United States', 'capital': 'Charlotte Amalie', 'country_code': 'VI', 'cc3': 'VIR', 'dialing_code': '+1 340', 'tiemzone': 'UTC-04', 'currency': 'United States dollar'}
# {'name': 'Wallis and Futuna', 'capital': 'Mata-Utu', 'country_code': 'WF', 'cc3': 'WLF', 'dialing_code': '+681', 'tiemzone': 'UTC+12:00', 'currency': 'CFP franc'}
# {'name': 'Western Sahara', 'capital': 'LaÃ¢youne (El AaiÃºn)', 'country_code': 'EH', 'cc3': 'ESH', 'dialing_code': '+212 5288/5289', 'tiemzone': 'UTC+01', 'currency': 'Moroccan dirham'}
# {'name': 'Yemen', 'capital': 'SanaÃ¡', 'country_code': 'YE', 'cc3': 'YEM', 'dialing_code': '+967', 'tiemzone': 'UTC+03:00', 'currency': 'Yemeni rial'}
# {'name': 'Zambia', 'capital': 'Lusaka', 'country_code': 'ZM', 'cc3': 'ZMB', 'dialing_code': '+260', 'tiemzone': 'UTC+02:00', 'currency': 'Zambian kwacha'}
# {'name': 'Zimbabwe', 'capital': ' Harare', 'country_code': 'ZW', 'cc3': 'ZWE', 'dialing_code': '+263', 'tiemzone': 'UTC+02:00', 'currency': 'Zimbabwean dollar'}
# {'afghanistan': {'name': 'Afghanistan', 'capital': 'Kabul', 'country_code': 'AF', 'cc3': 'AFG', 'dialing_code': '+93', 'tiemzone': 'UTC+04:30', 'currency': 'Afghan afghani'}, 'aland islands': {'name': 'Aland Islands', 'capital': 'Mariehamn', 'country_code': 'AX', 'cc3': 'ALA', 'dialing_code': '+358', 'tiemzone': 'UTC+02:00', 'currency': 'Euro'}, 'albania': {'name': 'Albania', 'capital': 'Tirana', 'country_code': 'AL', 'cc3': 'ALB', 'dialing_code': '+355', 'tiemzone': 'UTC+01:00', 'currency': 'Albanian lek'}, 'algeria': {'name': 'Algeria', 'capital': 'Algiers', 'country_code': 'DZ', 'cc3': 'DZA', 'dialing_code': '+213', 'tiemzone': 'UTC', 'currency': 'Algerian dinar'}, 'american samoa': {'name': 'American Samoa', 'capital': 'Pago Pago', 'country_code': 'AS', 'cc3': 'ASM', 'dialing_code': '+1 684', 'tiemzone': 'UTC-11:00', 'currency': ''}, 'andorra': {'name': 'Andorra', 'capital': 'Andorra la Vella', 'country_code': 'AD', 'cc3': 'AND', 'dialing_code': '+376', 'tiemzone': 'UTC+01:00', 'currency': 'Euro'}, 'angola': {'name': 'Angola', 'capital': 'Luanda', 'country_code': 'AO', 'cc3': 'AGO', 'dialing_code': '+244', 'tiemzone': 'UTC+01:00', 'currency': 'Angolan kwanza'}, 'anguilla': {'name': 'Anguilla', 'capital': 'The Valley', 'country_code': 'AI', 'cc3': 'AIA', 'dialing_code': '+1 264', 'tiemzone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}, 'antarctica': {'name': 'Antarctica', 'capital': '', 'country_code': 'AQ', 'cc3': 'ATA', 'dialing_code': '', 'tiemzone': '', 'currency': ''}, 'antigua and barbuda': {'name': 'Antigua and Barbuda', 'capital': "St. John's", 'country_code': 'AG', 'cc3': 'ATG', 'dialing_code': '+1 268', 'tiemzone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}, 'argentina': {'name': 'Argentina', 'capital': 'Buenos Aires', 'country_code': 'AR', 'cc3': 'ARG', 'dialing_code': '+54', 'tiemzone': 'UTC-03:00', 'currency': 'Argentine peso'}, 'armenia': {'name': 'Armenia', 'capital': 'Yerevan', 'country_code': 'AM', 'cc3': 'ARM', 'dialing_code': '+374', 'tiemzone': 'UTC+04:00', 'currency': 'Armenian dram'}, 'aruba': {'name': 'Aruba', 'capital': 'Oranjestad', 'country_code': 'AW', 'cc3': 'ABW', 'dialing_code': '+297', 'tiemzone': 'UTC-04:00', 'currency': 'Aruban florin'}, 'australia': {'name': 'Australia', 'capital': 'Canberra', 'country_code': 'AU', 'cc3': 'AUS', 'dialing_code': '+61', 'tiemzone': 'UTC+07:00 - UTC+10:00', 'currency': 'Australian dollar'}, 'austria': {'name': 'Austria', 'capital': 'Vienna', 'country_code': 'AT', 'cc3': 'AUT', 'dialing_code': '+43', 'tiemzone': 'UTC+01:00', 'currency': 'Euro'}, 'azerbaijan': {'name': 'Azerbaijan', 'capital': 'Baku', 'country_code': 'AZ', 'cc3': 'AZE', 'dialing_code': '+994', 'tiemzone': 'UTC+04:00', 'currency': 'Azerbaijani manat'}, 'bahamas': {'name': 'Bahamas', 'capital': 'Nassau', 'country_code': 'BS', 'cc3': 'BHS', 'dialing_code': '+1 242', 'tiemzone': 'UTC-05:00', 'currency': 'Bahamian dollar'}, 'bahrain': {'name': 'Bahrain', 'capital': 'Manama', 'country_code': 'BH', 'cc3': 'BHR', 'dialing_code': '+973', 'tiemzone': 'UTC+03:00', 'currency': 'Bahraini dinar'}, 'bangladesh': {'name': 'Bangladesh', 'capital': 'Dhaka', 'country_code': 'BD', 'cc3': 'BGD', 'dialing_code': '+880', 'tiemzone': 'UTC+06:00', 'currency': 'Bangladeshi taka'}, 'barbados': {'name': 'Barbados', 'capital': 'Bridgetown', 'country_code': 'BB', 'cc3': 'BRB', 'dialing_code': '+1 246', 'tiemzone': 'UTC-04:00', 'currency': 'Barbadian dollar'}, 'belarus': {'name': 'Belarus', 'capital': 'Minsk', 'country_code': 'BY', 'cc3': 'BLR', 'dialing_code': '+375', 'tiemzone': 'UTC+03:00', 'currency': 'Belarusian ruble'}, 'belgium': {'name': 'Belgium', 'capital': 'Brussels', 'country_code': 'BE', 'cc3': 'BEL', 'dialing_code': '+32', 'tiemzone': 'UTC+01:00', 'currency': 'Euro'}, 'belize': {'name': 'Belize', 'capital': 'Belmopan', 'country_code': 'BZ', 'cc3': 'BLZ', 'dialing_code': '+501', 'tiemzone': 'UTC-06:00', 'currency': 'Belize dollar'}, 'benin': {'name': 'Benin', 'capital': 'Porto-Novo', 'country_code':  ...

# %%
while True:
    chosen_country = input('please enter the name of a country:').casefold()
    if chosen_country in countries:
        country_data = countries[chosen_country]
        print(f"The capital of {chosen_country} is {country_data['capital']}")
    elif chosen_country == 'quit':
        break
# Out:
# please enter the name of a country:india
# The capital of india is New Delhi
# please enter the name of a country:quit

# %%
import datetime
from os import SEEK_SET
from typing import TextIO


def get_year() -> int:
    """Return the current year as an integer."""
    return datetime.datetime.now().year


def parse_invoice_number(invoice_number: str) -> tuple[int, int]:
    """Split a well-formed invoice "number" into its component parts.

    :param invoice_number: A string of the form YYYY-NNNN
        YYYY is the 4 digit year.
        NNNN is a 4 digit invoice number, left padded with zeros.
        The 2 parts are separated with a "-" character.
    :return: The returned tuple will contain:
        the 4 digit year as an integer,
        the invoice number as an integer.
    """
    year, number = invoice_number.split('-')
    return int(year), int(number)


def next_invoice_number(invoice_number: str) -> str:
    """ Produce the next invoice "number" in sequence.

    The format of `invoice_number` is described in `parse_invoice_number`.

    :param invoice_number: A string representing an invoice number.
    :return: A string representing the next invoice number.
        The numerical part will be incremented, unless the current year
        isn't the same as the year in `invoice_number`. In that case,
        the new invoice number will contain the current year, and the
        numerical part will be set to "0001".
    """
    invoice_year, number = parse_invoice_number(invoice_number)
    year = get_year()
    if year == invoice_year:
        number += 1
    else:
        invoice_year = year
        number = 1
    new_invoice_number = f'{invoice_year}-{number:04d}'
    return new_invoice_number


def record_invoice(invoice_file: TextIO,
                   company: str,
                   amount: float) -> int:
    """Create a new invoice number, and write it to a file on disk.

    :param invoice_file: An open text file, opened using r+.
    :param company: The name of the company being invoiced.
    :param amount: The amount of the invoice.
    :param last_line_ptr: The position of the start of the last
        line in the file. This will be obtained by the previous
        call to `record_invoice`.
    :return: The position of the start of the last line in the file.
        This can be used in subsequent calls to `record_invoice`.
    """
    last_line_ptr = 0
    invoice_file.seek(last_line_ptr, SEEK_SET)
    last_row = ''
    for line in invoice_file:
        print('*', end='')  # TODO delete after testing
        last_row = line
    if last_row:
        # invoice_number, _, _ = last_row.split('\t')
        invoice_number = last_row.split('\t')[0]
        new_invoice_number = next_invoice_number(invoice_number)
    else:
        # if the file is empty, we'll start numbering from 1.
        year = get_year()
        new_invoice_number = f'{year}-{1:04d}'

    last_line_ptr = invoice_file.tell()
    print(f'{new_invoice_number}\t{company}\t{amount}', file=invoice_file)
    return last_line_ptr


data_file = 'invoices.csv'

with open(data_file, 'r+') as invoices:
    record_invoice(invoices, 'ACME Roadrunner', 18.40)
    record_invoice(invoices, 'Squirrel Storage', 320.55)

# Test code:
# current_year = get_year()
# test_data = [
#     ('2019-0005', (2019, 5), f'{current_year}-0001'),
#     (f'{current_year}-8514', (current_year, 8514), f'{current_year}-8515'),
#     (f'{current_year}-0001', (current_year, 1), f'{current_year}-0002'),
#     (f'{current_year}-0023', (current_year, 23), f'{current_year}-0024'),
# ]
#
# for test_string, result, next_number in test_data:
#     parts = parse_invoice_number(test_string)
#     if parts == result:
#         print(f'{test_string} parsed successfully')
#     else:
#         print(f'{test_string} failed to parse. Expected {result} got {parts}')
#
#     new_number = next_invoice_number(test_string)
#     if next_number == new_number:
#         print(f'New number {new_number} generated correctly for {test_string}')
#     else:
#         print(f'New number {new_number} is not correct for {test_string}')
#
#     print('-' * 80)
# Out:
# *************************************************

# %% [markdown]
# > #### Seek and Tell.
# > https://docs.python.org/3/library/io.html#id1
